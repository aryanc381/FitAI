# %%
# !pip show opencv-python mediapipe
# Out:
# Name: opencv-python
# Version: 4.10.0.84
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/opencv/opencv-python
# Author:
# Author-email:
# License: Apache 2.0
# Location: C:\Python312\Lib\site-packages
# Requires: numpy
# Required-by:
# ---
# Name: mediapipe
# Version: 0.10.21
# Summary: MediaPipe is the simplest way for researchers and developers to build world-class ML solutions and applications for mobile, edge, cloud and the web.
# Home-page: https://github.com/google/mediapipe
# Author: The MediaPipe Authors
# Author-email: mediapipe@google.com
# License: Apache 2.0
# Location: C:\Python312\Lib\site-packages
# Requires: absl-py, attrs, flatbuffers, jax, jaxlib, matplotlib, numpy, opencv-contrib-python, protobuf, sentencepiece, sounddevice
# Required-by:
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Python312\Lib\site-packages)
# ...

# %%
import cv2
import numpy as np

import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils # all the viz of the poses
mp_pose = mp.solutions.pose # loading the pose model

# %%
print("success")
# Out:
# success

# %%
# Setting up the video capturing code block
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow("Mediapipe feed", frame)

    if cv2.waitKey(10) & 0xFF == ord('q'): # here 10 means the minimum key press time is 10 milliseconds 
        break

cap.release()
cv2.destroyAllWindows()
print("The video feed code-block is functioning : SUCCESS")
# Out:
# The video feed code-block is functioning : SUCCESS

# %%
import cv2
import mediapipe as mp

# Initialize Mediapipe Pose and Drawing Utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Start video capture
cap = cv2.VideoCapture(0)

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("Unable to read from the video feed. Exiting...")
            break

        # Convert BGR to RGB for Mediapipe processing
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False  # Optimize performance by making the image read-only

        # Process the image with the Pose model
        results = pose.process(image)

        # Draw pose landmarks on the original image
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))
        cv2.imshow('Pose Detection Feed', frame)

        # Exit the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Pose detection completed!")
# Out:
# Pose detection completed!

# %%
# !pip install protobuf==3.20.3

# %%
# setting up the mediapipe pose detecion block
cap = cv2.VideoCapture(0)
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence = 0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()

        # our processing model requires image in rgb format hence we are converting it using cv2 library
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) 
        # reducing processing power required by converting image to array
        image.flags.writeable = False

        result = pose.process(image) # using the model to track images

        image.flags.writeable = True # now converting it back (array -> image)
        image = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR) # converting it back to BGR format as cv2 requires that format
        print(result)
        
        cv2.imshow("Mediapipe feed", frame)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
print("The rendering block is working fine.")
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# The rendering block is working fine.

# %%
pip show protobuf
# Out:
# Name: protobufNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python312\Lib\site-packages)
# Version: 4.25.6
# Summary:
# Home-page: https://developers.google.com/protocol-buffers/
# Author: protobuf@googlegroups.com
# Author-email: protobuf@googlegroups.com
# License: 3-Clause BSD License
# Location: C:\Python312\Lib\site-packages
# Requires:
# Required-by: mediapipe, streamlit, tensorboard, tensorflow-intel

# %%
pip list | findstr protobuf
# Out:
# protobuf                  4.25.6
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (C:\Python312\Lib\site-packages)

# %%
# !python -V
# Out:
# Python 3.12.4

# %%
import cv2
import mediapipe as mp

# Initialize Mediapipe Pose and Drawing Utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Start video capture
cap = cv2.VideoCapture(0)

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("Unable to read from the video feed. Exiting...")
            break

        # Convert BGR to RGB for Mediapipe processing
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False  # Optimize performance by making the image read-only

        # Process the image with the Pose model
        results = pose.process(image)

        # Draw pose landmarks on the original image
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))
        cv2.imshow('Pose Detection Feed', image)

        # Exit the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Pose detection completed!")
# Out:
# Pose detection completed!

# %%
mp_pose.POSE_CONNECTIONS
# Out:
# frozenset({(<PoseLandmark.NOSE: 0>, <PoseLandmark.LEFT_EYE_INNER: 1>),
#            (<PoseLandmark.NOSE: 0>, <PoseLandmark.RIGHT_EYE_INNER: 4>),
#            (<PoseLandmark.LEFT_EYE_INNER: 1>, <PoseLandmark.LEFT_EYE: 2>),
#            (<PoseLandmark.LEFT_EYE: 2>, <PoseLandmark.LEFT_EYE_OUTER: 3>),
#            (<PoseLandmark.LEFT_EYE_OUTER: 3>, <PoseLandmark.LEFT_EAR: 7>),
#            (<PoseLandmark.RIGHT_EYE_INNER: 4>, <PoseLandmark.RIGHT_EYE: 5>),
#            (<PoseLandmark.RIGHT_EYE: 5>, <PoseLandmark.RIGHT_EYE_OUTER: 6>),
#            (<PoseLandmark.RIGHT_EYE_OUTER: 6>, <PoseLandmark.RIGHT_EAR: 8>),
#            (<PoseLandmark.MOUTH_RIGHT: 10>, <PoseLandmark.MOUTH_LEFT: 9>),
#            (<PoseLandmark.LEFT_SHOULDER: 11>, <PoseLandmark.LEFT_ELBOW: 13>),
#            (<PoseLandmark.LEFT_SHOULDER: 11>, <PoseLandmark.LEFT_HIP: 23>),
#            (<PoseLandmark.RIGHT_SHOULDER: 12>,
#             <PoseLandmark.LEFT_SHOULDER: 11>),
# ...

# %%
mp_drawing.draw_landmarks??
# Out:
# Signature:
# mp_drawing.draw_landmarks(
#     image: numpy.ndarray,
#     landmark_list: mediapipe.framework.formats.landmark_pb2.NormalizedLandmarkList,
#     connections: Union[List[Tuple[int, int]], NoneType] = None,
#     landmark_drawing_spec: Union[mediapipe.python.solutions.drawing_utils.DrawingSpec, Mapping[int, mediapipe.python.solutions.drawing_utils.DrawingSpec]] = DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
#     connection_drawing_spec: Union[mediapipe.python.solutions.drawing_utils.DrawingSpec, Mapping[Tuple[int, int], mediapipe.python.solutions.drawing_utils.DrawingSpec]] = DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
# )
# Source:
# def draw_landmarks(
#     image: np.ndarray,
#     landmark_list: landmark_pb2.NormalizedLandmarkList,
#     connections: Optional[List[Tuple[int, int]]] = None,
#     landmark_drawing_spec: Union[DrawingSpec,
#                                  Mapping[int, DrawingSpec]] = DrawingSpec(
# ...

# %%
from IPython.display import display, Image

img = Image(url="https://i.imgur.com/3j8BPdc.png")
display(img)
# Out:
# <img src="https://i.imgur.com/3j8BPdc.png"/>

# %%
# import cv2
# import mediapipe as mp

# # Initialize Mediapipe Pose and Drawing Utilities
# mp_pose = mp.solutions.pose
# mp_drawing = mp.solutions.drawing_utils

# # Start video capture
# cap = cv2.VideoCapture(0)

# with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#     while cap.isOpened():
#         ret, frame = cap.read()
#         if not ret:
#             print("Unable to read from the video feed. Exiting...")
#             break

#         # Convert BGR to RGB for Mediapipe processing
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         image.flags.writeable = False  # Optimize performance by making the image read-only

#         # Process the image with the Pose model
#         results = pose.process(image)

#         # extract landmarks
#         try:
#             landmarks = results.pose_landmarks.landmark
#             print(landmarks)
#         except:
#             pass

#         # Draw pose landmarks on the original image
#         image.flags.writeable = True
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#         mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
#                                   mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
#                                   mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))
#         cv2.imshow('Pose Detection Feed', image)

#         # Exit the loop if 'q' is pressed
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break

# # Release resources
# cap.release()
# cv2.destroyAllWindows()
# print("Pose detection completed!")

# %%
len(landmarks)
# Out:
# 33

# %%
for lndmrk in mp_pose.PoseLandmark:
    print(lndmrk)
# Out:
# PoseLandmark.NOSE
# PoseLandmark.LEFT_EYE_INNER
# PoseLandmark.LEFT_EYE
# PoseLandmark.LEFT_EYE_OUTER
# PoseLandmark.RIGHT_EYE_INNER
# PoseLandmark.RIGHT_EYE
# PoseLandmark.RIGHT_EYE_OUTER
# PoseLandmark.LEFT_EAR
# PoseLandmark.RIGHT_EAR
# PoseLandmark.MOUTH_LEFT
# PoseLandmark.MOUTH_RIGHT
# PoseLandmark.LEFT_SHOULDER
# PoseLandmark.RIGHT_SHOULDER
# PoseLandmark.LEFT_ELBOW
# PoseLandmark.RIGHT_ELBOW
# PoseLandmark.LEFT_WRIST
# PoseLandmark.RIGHT_WRIST
# PoseLandmark.LEFT_PINKY
# PoseLandmark.RIGHT_PINKY
# PoseLandmark.LEFT_INDEX
# PoseLandmark.RIGHT_INDEX
# PoseLandmark.LEFT_THUMB
# PoseLandmark.RIGHT_THUMB
# PoseLandmark.LEFT_HIP
# PoseLandmark.RIGHT_HIP
# PoseLandmark.LEFT_KNEE
# PoseLandmark.RIGHT_KNEE
# PoseLandmark.LEFT_ANKLE
# PoseLandmark.RIGHT_ANKLE
# PoseLandmark.LEFT_HEEL
# PoseLandmark.RIGHT_HEEL
# PoseLandmark.LEFT_FOOT_INDEX
# PoseLandmark.RIGHT_FOOT_INDEX

# %%
mp_pose.PoseLandmark.LEFT_SHOULDER.value
# Out:
# 11

# %%
mp_pose.PoseLandmark.NOSE.value
# Out:
# 0

# %%
import numpy as np  # Make sure this is at the top too!

def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Middle point
    c = np.array(c)  # End point

    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians * 180.0 / np.pi)

    if angle > 180.0:
        angle = 360 - angle

    return angle

# %%
shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

# %%
shoulder, elbow, wrist
# Out:
# ([0.7695603370666504, 0.6695873737335205],
#  [0.90818852186203, 1.0028748512268066],
#  [0.8178194761276245, 1.2241548299789429])

# %%
calculate_angle(shoulder, elbow, wrist)
# Out:
# 135.200805709708

# %%
    import cv2
    import numpy as np
    import mediapipe as mp
    
    # -------------------- VARIABLES ---------------------------
    # Initialize Mediapipe Pose and Drawing Utilities
    mp_pose = mp.solutions.pose
    mp_drawing = mp.solutions.drawing_utils
    
    counter_left = 0
    counter_right = 0
    stage = None
    
        # ----------------------------- ANGLE FUNCTION ----------------------------------------------
        
    def calculate_angle(a, b, c):
            """Returns the angle between three points."""
            a = np.array(a)  # First
            b = np.array(b)  # Mid
            c = np.array(c)  # End
        
            radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
            angle = np.abs(radians * 180.0 / np.pi)
            if angle > 180.0:
                angle = 360 - angle
            return angle
        
    # ------------------------------------ Capture Video --------------------------------------------
    cap = cv2.VideoCapture(0)
    
    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                print("Unable to read from the video feed. Exiting...")
                break
    
            # Convert BGR to RGB for Mediapipe processing
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
    
            # Process the image with the Pose model
            results = pose.process(image)
    
            # Convert back to BGR for OpenCV
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
            try:
                landmarks = results.pose_landmarks.landmark
    
                # ELBOW LEFT
                shoulder_left = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                                 landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                elbow_left = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,
                              landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                wrist_left = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,
                              landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
    
                # ELBOW RIGHT
                shoulder_right = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,
                                  landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                elbow_right = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,
                               landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
                wrist_right = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,
                               landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
    
                # HIP RIGHT
                hip_right = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,
                            landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
                knee_right = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,
                             landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
                ankle_right = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,
                              landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
    
                # HIP LEFT
                hip_left = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,
                            landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
                knee_left = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,
                             landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
                ankle_left = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,
                              landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
    
                
                
    
                # Calculate angles
                angle_left_elbow = calculate_angle(shoulder_left, elbow_left, wrist_left)
                angle_right_elbow = calculate_angle(shoulder_right, elbow_right, wrist_right)
                angle_right_hip = calculate_angle(hip_left, hip_right, knee_right)
                angle_left_hip = calculate_angle(hip_right, hip_left, knee_left)
    
                # Coordinates
    
                # 1. LEFT ELBOW
                coords_left_elbow = tuple(np.multiply(elbow_left, [frame.shape[1], frame.shape[0]]).astype(int))
                cv2.putText(image, str(int(angle_left_elbow)), coords_left_elbow, cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_AA)
    
                # 2. RIGHT ELBOW
                coords_right_elbow = tuple(np.multiply(elbow_right, [frame.shape[1], frame.shape[0]]).astype(int))
                cv2.putText(image, str(int(angle_right_elbow)), coords_right_elbow, cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_AA)
    
                # 3. RIGHT HIP
                coords_right_hip = tuple(np.multiply(hip_right, [frame.shape[1], frame.shape[0]]).astype(int))
                cv2.putText(image, str(int(angle_right_hip)), coords_right_hip, cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_AA)
    
                # 4. LEFT HIP
                coord_left_hip = tuple(np.multiply(hip_left, [frame.shape[1], frame.shape[0]]).astype(int))
                cv2.putText(image, str(int(angle_left_hip)), coord_left_hip, cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_AA)
                
                # Draw pose landmarks
                mp_drawing.draw_landmarks(
                    image,
                    results.pose_landmarks,
                    mp_pose.POSE_CONNECTIONS,
                    mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                    mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                    
                )
    
            except:
                pass
    
            cv2.imshow('Mediapipe Feed', image)
    
            # Exit on 'q' key
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
    
    # Release resources
    cap.release()
    cv2.destroyAllWindows()
    print("Pose detection completed!")
# Out:
# Pose detection completed!

# %%
# def bodypart_right(part1, part2, part3):
#     joint1 = [landmark[mp_pose.Poselandmarks.""].x,
#               landmark[mp_pose.Poselandmarks.""].y]

# %%
from IPython.display import display, Image

img = Image(url="https://i.imgur.com/3j8BPdc.png")
display(img)
# Out:
# <img src="https://i.imgur.com/3j8BPdc.png"/>

# %%
def calculate_angle(a, b, c):
            """Returns the angle between three points."""
            a = np.array(a)  # First
            b = np.array(b)  # Mid
            c = np.array(c)  # End
        
            radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
            angle = np.abs(radians * 180.0 / np.pi)
            if angle > 180.0:
                angle = 360 - angle
            return angle

# %%
# -------------------- VARIABLES ---------------------------

# Initialize Mediapipe Pose and Drawing Utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

counter_left = 0
counter_right = 0
stage_left = None
stage_right = None

# ------------------------------------ Capture Video --------------------------------------------
cap = cv2.VideoCapture(0)

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("Unable to read from the video feed. Exiting...")
            break

        # Convert BGR to RGB for Mediapipe processing
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

# ------------------------------------- Capture pose ----------------------------------------------

        # 1. Process the image with the Pose model
        results = pose.process(image)

        # 2. Extract landmarks and calculate angle
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            landmarks = results.pose_landmarks.landmark


# ------------------------------------- Get coordinates ----------------------------------------
            
            # 1. Get coordinates for LEFT shoulder, elbow, and wrist
            shoulder_left = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                        landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow_left = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,
                     landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist_left = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,
                     landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            # 2. Get coordinates for LEFT shoulder, elbow, and wrist
            shoulder_right = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,
                        landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            elbow_right = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            wrist_right = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]

            # 3. Calculate angle
            angle_left = calculate_angle(shoulder_left, elbow_left, wrist_left)
            angle_right = calculate_angle(shoulder_right, elbow_right, wrist_right)

            # 4. Display angle on the frame near the elbow
            coords_left = tuple(np.multiply(elbow_left, [frame.shape[1], frame.shape[0]]).astype(int))
            # cv2.putText(image, str(int(angle_left)), coords_left,
                        # cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_AA)
            coords_right = tuple(np.multiply(elbow_right, [frame.shape[1], frame.shape[0]]).astype(int))
            # cv2.putText(image, str(int(angle_right)), coords_right,
                        # cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_AA)


# ------------------------------ Bicep Curl ------------------------------------------

        except Exception as e:
            print("Error calculating angle:", e)

        # curl counter logic
        if angle_left > 160:
            stage_left = "down"
        if angle_left < 35 and stage_left =="down":
            stage_left ="up"
            counter_left+=1
            print("The left bicep : ", counter_left)

        if angle_right > 160:
            stage_right = "down"
        if angle_right < 35 and stage_right =="down":
            stage_right ="up"
            counter_right+=1
            print("The right bicep : ", counter_right)

# ------------------------------ Display -----------------------------------------------

        # 1. The status bar on top
        height, width, _ = image.shape
        box_width = 650
        box_height = 50
        top_left = (width //2 - box_width //2, 0)
        bottom_right = (width //2 + box_width //2, 0 + box_height)
        cv2.rectangle(image, top_left, bottom_right, (0, 0, 0), -1)

        # 2. The reps word for left hand
        cv2.putText(image, 'REPS', (width-(width-1),height-(height-15)),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 1, cv2.LINE_AA)

        cv2.putText(image, str(counter_left), (width-(width-1),height-(height-45)), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)

        # 3. The reps word for the right hand
        cv2.putText(image, 'REPS', (0 + (width - 45), height-(height - 15)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)

        cv2.putText(image, str(counter_right), (0 + (width- 45),height-(height-45)), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        # 3. Draw pose landmarks
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # 4. Flipping the video
        thresh = 50 
        top = image[:thresh, :]
        bottom = image[thresh:, :]

        flipped_bottom = cv2.flip(bottom, 1)
        combined = np.vstack((top, flipped_bottom))
        # 5. Display the frame
        cv2.imshow('Pose Detection Feed', combined)

        # 6. Exit on 'q' key
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Pose detection completed!")
# Out:
# The left bicep :  1
# The right bicep :  1
# The right bicep :  2
# The right bicep :  3
# The right bicep :  4
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# Error calculating angle: 'NoneType' object has no attribute 'landmark'
# ...

# %%
# -------------------- VARIABLES ---------------------------

# Initialize Mediapipe Pose and Drawing Utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

counter_left = 0
counter_right = 0
stage_left = None
stage_right = None

# ------------------------------------ Capture Video --------------------------------------------
cap = cv2.VideoCapture(0)

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("Unable to read from the video feed. Exiting...")
            break

        # Convert BGR to RGB for Mediapipe processing
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

# ------------------------------------- Capture pose ----------------------------------------------

        # 1. Process the image with the Pose model
        results = pose.process(image)

        # 2. Extract landmarks and calculate angle
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            landmarks = results.pose_landmarks.landmark


# ------------------------------------- Get coordinates ----------------------------------------
            
            # 1. Get coordinates for LEFT shoulder, elbow, and wrist
            shoulder_left = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                        landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow_left = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,
                     landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist_left = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,
                     landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            # 2. Get coordinates for LEFT shoulder, elbow, and wrist
            shoulder_right = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,
                        landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            elbow_right = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            wrist_right = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]

            # 3. Calculate angle
            angle_left = calculate_angle(shoulder_left, elbow_left, wrist_left)
            angle_right = calculate_angle(shoulder_right, elbow_right, wrist_right)

            # 4. Display angle on the frame near the elbow
            coords_left = tuple(np.multiply(elbow_left, [frame.shape[1], frame.shape[0]]).astype(int))
            # cv2.putText(image, str(int(angle_left)), coords_left,
                        # cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_AA)
            coords_right = tuple(np.multiply(elbow_right, [frame.shape[1], frame.shape[0]]).astype(int))
            # cv2.putText(image, str(int(angle_right)), coords_right,
                        # cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_AA)


# ------------------------------ Bicep Curl ------------------------------------------

        except Exception as e:
            print("Error calculating angle:", e)


        # if hath neeche hein, then ok -> hath upar aya but didnt cross theta -> hath neeche -> do the complte rep take it till the end.
        # curl counter logic
        # if angle_left > 160:
        #     stage_left = "down"
            
        # if angle_left < 35 and stage_left =="down":
        #     stage_left ="up"
        # if angle_left > 35 and angle_left < 160 and stage_left=="down":
        #     print("Do the entire rep, dont do it half way")
        # if angle_left > 160 and stage_left ="up"
        #     counter_left+=1
        #     print("The left bicep : ", counter_left)


        if angle_left > 160:
            stage_left = "down"

        if angle_left < 35 and stage_left == "down":
            stage_left = "up"
            counter_left += 1
            print("The left bicep : ", counter_left)    
        elif angle_left >= 35 and angle_left < 160 and stage_left == "down":
            print("Left arm: Do the rep correctly")      
        if angle_right > 160:
            stage_right = "down"
        if angle_right < 35 and stage_right =="down":
            stage_right ="up"
            counter_right+=1
            print("The right bicep : ", counter_right)

# ------------------------------ Display -----------------------------------------------

        # 1. The status bar on top
        height, width, _ = image.shape
        box_width = 650
        box_height = 50
        top_left = (width //2 - box_width //2, 0)
        bottom_right = (width //2 + box_width //2, 0 + box_height)
        cv2.rectangle(image, top_left, bottom_right, (0, 0, 0), -1)

        # 2. The reps word for left hand
        cv2.putText(image, 'REPS', (width-(width-1),height-(height-15)),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 1, cv2.LINE_AA)

        cv2.putText(image, str(counter_left), (width-(width-1),height-(height-45)), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)

        # 3. The reps word for the right hand
        cv2.putText(image, 'REPS', (0 + (width - 45), height-(height - 15)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)

        cv2.putText(image, str(counter_right), (0 + (width- 45),height-(height-45)), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        # 3. Draw pose landmarks
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # 4. Flipping the video
        thresh = 50 
        top = image[:thresh, :]
        bottom = image[thresh:, :]

        flipped_bottom = cv2.flip(bottom, 1)
        combined = np.vstack((top, flipped_bottom))
        # 5. Display the frame
        cv2.imshow('Pose Detection Feed', combined)

        # 6. Exit on 'q' key
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Pose detection completed!")
# Out:
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# The left bicep :  1
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# The right bicep :  1
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# The right bicep :  2
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# Left arm: Do the rep correctly
# ...
